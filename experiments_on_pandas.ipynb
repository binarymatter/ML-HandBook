# %%
import pandas as pd

# %%
newf = pd.read_csv("car-sales.csv")

# %%
newf["Price"] = newf["Price"].str.replace('[$,]','').astype(float)

# %%
newf
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
newf
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
# Select the rows with over 100,000 kilometers on the Odometer
newf[newf["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4  4000.0
# 4  Nissan  White         213095      4  3500.0

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(newf["Make"], newf["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
newf[newf["Make"]== "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors   Price
# 0  Toyota  White         150043      4  4000.0
# 2  Toyota   Blue          32549      3  7000.0
# 5  Toyota  Green          99213      4  4500.0
# 8  Toyota  White          60000      4  6250.0

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
colours = pd.Series(["Red", "Blue", "Green", "Yellow"] )

# %%
colours
# Out:
# 0       Red
# 1      Blue
# 2     Green
# 3    Yellow
# dtype: object

# %%
cd = pd.Series({'C':'Cat', 'D':'Dog'})

# %%
cd
# Out:
# C    Cat
# D    Dog
# dtype: object

# %%
cd.iloc['C']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-752d20b2529a> in <module>
# ----> 1 cd.iloc['C']
#
# ~/Desktop/first_project/env/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~/Desktop/first_project/env/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2133             key = item_from_zerodim(key)
#    2134             if not is_integer(key):
# -> 2135                 raise TypeError("Cannot index by location index with a non-integer key")
#    2136
#    2137             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
coll = pd.DataFrame({'Animals': cd, 'Colour':colours})

# %%
coll
# Out:
#   Animals  Colour
# C     Cat     NaN
# D     Dog     NaN
# 0     NaN     Red
# 1     NaN    Blue
# 2     NaN   Green
# 3     NaN  Yellow

# %% [markdown]
# ## If the plot doesnt work type in
# %matplotlib inline
# import matplotlib.pyplot as plt

# %%
pd.crosstab(car_sales["Make"], car_sales["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
import matplotlib.pyplot as plt

# %%
car_sales["Odometer (KM)"].hist()
